# %%
import numpy as np
import pandas as pd
import plotly.express as px
from datetime import date

# %% [markdown]
# Data Ingestion

# %%
df_car = pd.read_csv(r'D:\AWS\usedcar\car_data.csv')
df_mod=pd.read_csv(r'D:\AWS\usedcar\model_data.csv')

# %% [markdown]
# Top 5 rows for data set

# %%
df_car.head()
# Out:
#                 Model  Selling Price  Kilometers Driven  Year        Owner
# 0  MarutiWagonR1.0LXI         312165              82238  2014  First Owner  \
# 1     ToyotaEtiosLiva         313799              30558  2013  First Owner
# 2       MarutiAlto800         295999              22164  2018  First Owner
# 3         MarutiSwift         435199              30535  2013  First Owner
# 4     MarutiWagonR1.0         289099              15738  2013  First Owner
#
#       Fuel Type Transmission   Insurance  Car Condition
# 0  Petrol + CNG       MANUAL     Expired            4.2
# 1        Petrol       MANUAL  12-09-2021            4.4
# 2        Petrol       MANUAL  01-12-2020            4.8
# 3        Diesel       MANUAL        Comp            4.3
# 4        Petrol       MANUAL  11-08-2021            4.3

# %%
df_mod.head()
# Out:
#                              Model Current Price
# 0  HyundaiElitei20Sportz(O)1.4CRDi  Rs.7.69 Lakh
# 1       MarutiErtigaZXISMARTHYBRID  Rs.9.27 Lakh
# 2            MarutiVitaraBrezzaLDI   Rs.7,62,742
# 3     FordEcosport1.5TITANIUMTIVCT  Rs.7.64 Lakh
# 4       HyundaiVernaFLUIDIC1.4CRDI   Rs.9,99,900

# %% [markdown]
# join both tables on model colmuns

# %%
df = pd.merge(df_car, df_mod, left_on='Model', right_on='Model')

# %% [markdown]
# Using describe to check all the possible values

# %%
df.describe(include='all')
# Out:
#               Model  Selling Price  Kilometers Driven         Year
# count          2237   2.237000e+03        2237.000000  2237.000000  \
# unique          434            NaN                NaN          NaN
# top     MarutiSwift            NaN                NaN          NaN
# freq            118            NaN                NaN          NaN
# mean            NaN   4.184431e+05       61928.605275  2013.763523
# std             NaN   2.280516e+05       42260.955917     2.874686
# min             NaN   7.529900e+04         913.000000  2006.000000
# 25%             NaN   2.720990e+05       32137.000000  2012.000000
# 50%             NaN   3.557990e+05       55430.000000  2014.000000
# 75%             NaN   5.032990e+05       83427.000000  2016.000000
# max             NaN   1.952397e+06      855881.000000  2020.000000
#
#               Owner Fuel Type Transmission Insurance  Car Condition
# count          2237      2237         2237      2223    2237.000000  \
# unique            3         4           58       473            NaN
# top     First Owner    Petrol       MANUAL   Expired            NaN
# freq           1707      1384         1909       248            NaN
# mean            NaN       NaN          NaN       NaN       4.370854
# std             NaN       NaN          NaN       NaN       0.288990
# min             NaN       NaN          NaN       NaN       3.000000
# 25%             NaN       NaN          NaN       NaN       4.200000
# 50%             NaN       NaN          NaN       NaN       4.300000
# 75%             NaN       NaN          NaN       NaN       4.600000
# max             NaN       NaN          NaN       NaN       5.000000
#
#        Current Price
# count           2235
# unique           325
# top     Rs.5.49 Lakh
# freq             131
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %% [markdown]
# To check if there are any missing value in all colums

# %%
df.isna().mean()*100
# Out:
# Model                0.000000
# Selling Price        0.000000
# Kilometers Driven    0.000000
# Year                 0.000000
# Owner                0.000000
# Fuel Type            0.000000
# Transmission         0.000000
# Insurance            0.625838
# Car Condition        0.000000
# Current Price        0.089405
# dtype: float64

# %% [markdown]
# Plotting histogram to observe the price of cars sold

# %%
fig = px.histogram(df, 'Selling Price')
fig.show()

# %%
df = df[df['Selling Price'] != 0]

# %% [markdown]
# The Function to change the format of selling prices
# Converts str to total numeric values

# %%
def format_price(price):
    price = str(price)
    price = price.replace('Rs.', '')
    price = price.replace(',', '')
    num_zeros = 5
    if '.' not in price and ' Lakh' in price:
        price = price.replace(' Lakh', '0'*num_zeros)
    elif '.' in price and ' Lakh in price':
        n = len(price)
        m = price.index('.')
        num_zeros = n - m - num_zeros
        price = price.replace(' Lakh', '0'*num_zeros)
        price = price.replace('.', '')
    return price

# %% [markdown]
# This to change the format for current price of the cars

# %%
df['Current Price'] = df['Current Price'].apply(format_price)
df[df['Current Price'] == 'nan'] = 0
df['Current Price'] = df['Current Price'].astype(int)

# %% [markdown]
# plotting histogram of current price

# %%
fig = px.histogram(df, 'Current Price')
fig.show()

# %% [markdown]
# Here below to find the how old the car is from the manufacturing year

# %%
year = date.today().year
df['Age'] = year - df['Year']

# %% [markdown]
# Scatter plot showing the Age of  and kilometer driven .

# %%
df = df[df['Selling Price'] != 0]
fig = px.scatter(x=df['Age'], y=df['Kilometers Driven'])
fig.show()

# %% [markdown]
# Scatter plot between Kilometers driven and selling price

# %%
fig = px.scatter(x=df['Kilometers Driven'], y=df['Selling Price'])
fig.show()

# %% [markdown]
# scatter plot for age and selling price of the cars

# %%
fig = px.scatter(x=df['Age'], y=df['Selling Price'])
fig.show()

# %%
df['No_Current_Price'] = 0
df.loc[df['Current Price'] == 0, 'No_Current_Price'] = 1

# %%
df['diff'] = df['Current Price'] - df['Selling Price']

# %% [markdown]
# To find the differnce between current price and selling price

# %%
med_diff = df[df['diff'] > 0]['diff'].median()

# %%
def set_current_price(row):
    if row['Current Price'] == 0 or row['diff'] < 0:
        row['Current Price'] = row['Selling Price'] + med_diff
    
    return row['Current Price']

df.loc[:, 'Current Price'] = df.apply(set_current_price, axis=1)

# %%
df.head()
# Out:
#                 Model  Selling Price  Kilometers Driven  Year         Owner
# 0  MarutiWagonR1.0LXI         312165              82238  2014   First Owner  \
# 1  MarutiWagonR1.0LXI         242499              88514  2015  Second Owner
# 2  MarutiWagonR1.0LXI         381699              29735  2017  Second Owner
# 3  MarutiWagonR1.0LXI         181999             153709  2013   First Owner
# 4  MarutiWagonR1.0LXI         239499              88691  2012  Second Owner
#
#       Fuel Type Transmission   Insurance  Car Condition  Current Price  Age
# 0  Petrol + CNG       MANUAL     Expired            4.2         465000    9  \
# 1  Petrol + CNG       MANUAL  26-07-2021            4.4         465000    8
# 2  Petrol + CNG       MANUAL  18-09-2021            4.3         465000    6
# 3  Petrol + CNG       MANUAL  25-05-2021            4.1         465000   10
# 4  Petrol + CNG       MANUAL  15-10-2021            4.4         465000   11
#
#    No_Current_Price    diff
# 0                 0  152835
# 1                 0  222501
# 2                 0   83301
# 3                 0  283001
# 4                 0  225501

# %%
df.head()
# Out:
#                 Model  Selling Price  Kilometers Driven  Year         Owner
# 0  MarutiWagonR1.0LXI         312165              82238  2014   First Owner  \
# 1  MarutiWagonR1.0LXI         242499              88514  2015  Second Owner
# 2  MarutiWagonR1.0LXI         381699              29735  2017  Second Owner
# 3  MarutiWagonR1.0LXI         181999             153709  2013   First Owner
# 4  MarutiWagonR1.0LXI         239499              88691  2012  Second Owner
#
#       Fuel Type Transmission   Insurance  Car Condition  Current Price  Age
# 0  Petrol + CNG       MANUAL     Expired            4.2         465000    9  \
# 1  Petrol + CNG       MANUAL  26-07-2021            4.4         465000    8
# 2  Petrol + CNG       MANUAL  18-09-2021            4.3         465000    6
# 3  Petrol + CNG       MANUAL  25-05-2021            4.1         465000   10
# 4  Petrol + CNG       MANUAL  15-10-2021            4.4         465000   11
#
#    No_Current_Price    diff
# 0                 0  152835
# 1                 0  222501
# 2                 0   83301
# 3                 0  283001
# 4                 0  225501

# %% [markdown]
# dropping the unsed columns

# %%
df.drop([ 'Year', 'Insurance', 'diff'], axis=1, inplace=True)
df.head()
# Out:
#                 Model  Selling Price  Kilometers Driven         Owner
# 0  MarutiWagonR1.0LXI         312165              82238   First Owner  \
# 1  MarutiWagonR1.0LXI         242499              88514  Second Owner
# 2  MarutiWagonR1.0LXI         381699              29735  Second Owner
# 3  MarutiWagonR1.0LXI         181999             153709   First Owner
# 4  MarutiWagonR1.0LXI         239499              88691  Second Owner
#
#       Fuel Type Transmission  Car Condition  Current Price  Age
# 0  Petrol + CNG       MANUAL            4.2         465000    9  \
# 1  Petrol + CNG       MANUAL            4.4         465000    8
# 2  Petrol + CNG       MANUAL            4.3         465000    6
# 3  Petrol + CNG       MANUAL            4.1         465000   10
# 4  Petrol + CNG       MANUAL            4.4         465000   11
#
#    No_Current_Price
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
X = df.drop(['Selling Price'], axis=1)
y = df.loc[:, 'Selling Price']

# %% [markdown]
# Relation between selling price and current price

# %%
df[["Current Price", "Selling Price"]].corr()
# Out:
#                Current Price  Selling Price
# Current Price       1.000000       0.537003
# Selling Price       0.537003       1.000000

# %%
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Grahp for kilometer driven and selling price we can the are driectly proportional

# %%
from matplotlib import pyplot


sns.regplot(x="Kilometers Driven", y="Selling Price", data=df)
pyplot.ylim(0,)
# Out:
# (0.0, 2076852.9893443733)

# %% [markdown]
# Plotting boxplot to see what is the price of diferent fule type

# %%
sns.boxplot(x="Fuel Type", y="Selling Price", data=df)#b
# Out:
# <Axes: xlabel='Fuel Type', ylabel='Selling Price'>

# %%
df['Transmission']. unique()
# Out:
# array(['MANUAL', 'MH12', 'TS07', 'KA01', 'MH05', 'DL5C', 'DL9C', 'MH04',
#        'TS08', 'AUTOMATIC', 'UP14', 'UP32', 'HR03', 'MH01', 'DL2C',
#        'KA05', 'KA50', 'KA53', 'DL12', 'DL11', 'GJ27', 'TN12', 'TN02',
#        'HR26', 'MH03', 'MH47', 'TS09', 'RJ14', 'TN06', 'MH43', 'DL4C',
#        'KA02', 'MH02', 'RJ45', 'DL3C', 'TN22', 'KA04', 'MH46', 'KA51',
#        'PB91', 'DL8C', 'GJ18', 'HR51', 'DL10', 'HR29', 'KA03', 'DL14',
#        'GJ05', 'GJ01', 'PB10', 'MH14', 'UP78', 'GJ06', 'Ch01', 'HR05',
#        'HR12', 'DL1C', 'PB11'], dtype=object)

# %%
def clean_transmission(trans):
    
    
    if 'MANUAL' != trans and 'AUTOMATIC' != trans:
        trans = "MANUAL"
    
    return trans

df['Transmission'] = df['Transmission'].apply(clean_transmission)

# %% [markdown]
# Boxplot for transmission and selling price

# %%
sns.boxplot(x="Transmission", y="Selling Price", data=df)
# Out:
# <Axes: xlabel='Transmission', ylabel='Selling Price'>

# %%
df.head()
# Out:
#                 Model  Selling Price  Kilometers Driven         Owner
# 0  MarutiWagonR1.0LXI         312165              82238   First Owner  \
# 1  MarutiWagonR1.0LXI         242499              88514  Second Owner
# 2  MarutiWagonR1.0LXI         381699              29735  Second Owner
# 3  MarutiWagonR1.0LXI         181999             153709   First Owner
# 4  MarutiWagonR1.0LXI         239499              88691  Second Owner
#
#       Fuel Type Transmission  Car Condition  Current Price  Age
# 0  Petrol + CNG       MANUAL            4.2         465000    9  \
# 1  Petrol + CNG       MANUAL            4.4         465000    8
# 2  Petrol + CNG       MANUAL            4.3         465000    6
# 3  Petrol + CNG       MANUAL            4.1         465000   10
# 4  Petrol + CNG       MANUAL            4.4         465000   11
#
#    No_Current_Price
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df['Car Condition']. unique()
# Out:
# array([4.2, 4.4, 4.3, 4.1, 4.5, 3.9, 4.6, 3.7, 4. , 4.7, 4.8, 4.9, 5. ,
#        3.5, 3.8, 3.4, 3.6, 3.2, 3. ])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2235 entries, 0 to 2236
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              2235 non-null   object
#  1   Selling Price      2235 non-null   int64
#  2   Kilometers Driven  2235 non-null   int64
#  3   Owner              2235 non-null   object
#  4   Fuel Type          2235 non-null   object
#  5   Transmission       2235 non-null   object
#  6   Car Condition      2235 non-null   float64
#  7   Current Price      2235 non-null   int32
#  8   Age                2235 non-null   int64
#  9   No_Current_Price   2235 non-null   int64
# dtypes: float64(1), int32(1), int64(4), object(4)
# memory usage: 183.3+ KB

# %% [markdown]
# Storing the cleaned data

# %%
df.to_csv('cleaned car.csv')

# %%
df.reset_index()
# Out:
#       index                          Model  Selling Price  Kilometers Driven
# 0         0             MarutiWagonR1.0LXI         312165              82238  \
# 1         1             MarutiWagonR1.0LXI         242499              88514
# 2         2             MarutiWagonR1.0LXI         381699              29735
# 3         3             MarutiWagonR1.0LXI         181999             153709
# 4         4             MarutiWagonR1.0LXI         239499              88691
# ...     ...                            ...            ...                ...
# 2230   2232              NissanMicraXEPLUS         138199              65120
# 2231   2233               ToyotaInnova2.5V         509899             131152
# 2232   2234         FordEcosport1.5TRENDTI        1001799               4400
# 2233   2235  HyundaiElitei20MagnaExecutive         643499              65667
# 2234   2236                    HyundaiEonD         212299              28016
#
#              Owner     Fuel Type Transmission  Car Condition  Current Price
# 0      First Owner  Petrol + CNG       MANUAL            4.2         465000  \
# 1     Second Owner  Petrol + CNG       MANUAL            4.4         465000
# 2     Second Owner  Petrol + CNG       MANUAL            4.3         465000
# 3      First Owner  Petrol + CNG       MANUAL            4.1         465000
# 4     Second Owner  Petrol + CNG       MANUAL            4.4         465000
# ...            ...           ...          ...            ...            ...
# 2230  Second Owner        Petrol       MANUAL            4.3         478000
# 2231   First Owner        Diesel       MANUAL            4.5        1197000
# 2232   First Owner        Petrol       MANUAL            5.0        1232750
# 2233   First Owner        Diesel       MANUAL            4.5         722198
# 2234   First Owner        Petrol       MANUAL            3.2         332000
#
#       Age  No_Current_Price
# 0       9                 0
# 1       8                 0
# 2       6                 0
# 3      10                 0
# 4      11                 0
# ...   ...               ...
# 2230   13                 0
# 2231   12                 0
# 2232    4                 0
# 2233    5                 0
# 2234   12                 0
#
# [2235 rows x 11 columns]

# %%
df.describe()
# Out:
#        Selling Price  Kilometers Driven  Car Condition  Current Price
# count   2.235000e+03        2235.000000    2235.000000   2.235000e+03  \
# mean    4.183821e+05       61950.293512       4.370872   7.813966e+05
# std     2.281439e+05       42271.114127       0.289022   5.762826e+05
# min     7.529900e+04         913.000000       3.000000   2.850000e+05
# 25%     2.720490e+05       32144.500000       4.200000   4.980000e+05
# 50%     3.555300e+05       55484.000000       4.300000   5.990000e+05
# 75%     5.029490e+05       83429.000000       4.600000   9.000000e+05
# max     1.952397e+06      855881.000000       5.000000   8.639399e+06
#
#                Age  No_Current_Price
# count  2235.000000       2235.000000
# mean      9.235794          0.012528
# std       2.875882          0.111250
# min       3.000000          0.000000
# 25%       7.000000          0.000000
# 50%       9.000000          0.000000
# 75%      11.000000          0.000000
# max      17.000000          1.000000

# %%
df[df['Selling Price']<6e6]
# Out:
#                               Model  Selling Price  Kilometers Driven
# 0                MarutiWagonR1.0LXI         312165              82238  \
# 1                MarutiWagonR1.0LXI         242499              88514
# 2                MarutiWagonR1.0LXI         381699              29735
# 3                MarutiWagonR1.0LXI         181999             153709
# 4                MarutiWagonR1.0LXI         239499              88691
# ...                             ...            ...                ...
# 2232              NissanMicraXEPLUS         138199              65120
# 2233               ToyotaInnova2.5V         509899             131152
# 2234         FordEcosport1.5TRENDTI        1001799               4400
# 2235  HyundaiElitei20MagnaExecutive         643499              65667
# 2236                    HyundaiEonD         212299              28016
#
#              Owner     Fuel Type Transmission  Car Condition  Current Price
# 0      First Owner  Petrol + CNG       MANUAL            4.2         465000  \
# 1     Second Owner  Petrol + CNG       MANUAL            4.4         465000
# 2     Second Owner  Petrol + CNG       MANUAL            4.3         465000
# 3      First Owner  Petrol + CNG       MANUAL            4.1         465000
# 4     Second Owner  Petrol + CNG       MANUAL            4.4         465000
# ...            ...           ...          ...            ...            ...
# 2232  Second Owner        Petrol       MANUAL            4.3         478000
# 2233   First Owner        Diesel       MANUAL            4.5        1197000
# 2234   First Owner        Petrol       MANUAL            5.0        1232750
# 2235   First Owner        Diesel       MANUAL            4.5         722198
# 2236   First Owner        Petrol       MANUAL            3.2         332000
#
#       Age  No_Current_Price
# 0       9                 0
# 1       8                 0
# 2       6                 0
# 3      10                 0
# 4      11                 0
# ...   ...               ...
# 2232   13                 0
# 2233   12                 0
# 2234    4                 0
# 2235    5                 0
# 2236   12                 0
#
# [2235 rows x 10 columns]

# %% [markdown]
# Data Modeling

# %%
X = df.drop(['Selling Price','Age','No_Current_Price','Current Price','Car Condition'], axis=1)
y = df.loc[:, 'Selling Price']

# %%
X
# Out:
#                               Model  Kilometers Driven         Owner
# 0                MarutiWagonR1.0LXI              82238   First Owner  \
# 1                MarutiWagonR1.0LXI              88514  Second Owner
# 2                MarutiWagonR1.0LXI              29735  Second Owner
# 3                MarutiWagonR1.0LXI             153709   First Owner
# 4                MarutiWagonR1.0LXI              88691  Second Owner
# ...                             ...                ...           ...
# 2232              NissanMicraXEPLUS              65120  Second Owner
# 2233               ToyotaInnova2.5V             131152   First Owner
# 2234         FordEcosport1.5TRENDTI               4400   First Owner
# 2235  HyundaiElitei20MagnaExecutive              65667   First Owner
# 2236                    HyundaiEonD              28016   First Owner
#
#          Fuel Type Transmission
# 0     Petrol + CNG       MANUAL
# 1     Petrol + CNG       MANUAL
# 2     Petrol + CNG       MANUAL
# 3     Petrol + CNG       MANUAL
# 4     Petrol + CNG       MANUAL
# ...            ...          ...
# 2232        Petrol       MANUAL
# 2233        Diesel       MANUAL
# 2234        Petrol       MANUAL
# 2235        Diesel       MANUAL
# 2236        Petrol       MANUAL
#
# [2235 rows x 5 columns]

# %%
y
# Out:
# 0        312165
# 1        242499
# 2        381699
# 3        181999
# 4        239499
#          ...
# 2232     138199
# 2233     509899
# 2234    1001799
# 2235     643499
# 2236     212299
# Name: Selling Price, Length: 2235, dtype: int64

# %% [markdown]
# Building the Predictive Models
# We have use Liner Regression

# %% [markdown]
# At first we have to split our data into a training set and a test set, on which the models can be evaluated on later.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['Model','Kilometers Driven','Fuel Type','Owner','Transmission']])
# Out:
# OneHotEncoder()

# %%
OneHotEncoder()
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['AudiA62.0', 'AudiA62.0TDIPREMIUM', 'AudiQ335TDI', 'BMW3Series',
#         'BMW3Series320D', 'BMW5Series', 'BMWX1SDRIVE', 'ChevroletBeatPS',
#         'ChevroletCruzeLTZ', 'ChevroletSparkLS', 'DatsunGo',
#         'DatsunGoREMIX', 'DatsunRediGo', 'DatsunRediGoT',
#         'FiatGrandPuntoACTIVE', 'FiatGrandPuntoDYNAMIC', 'FordEcosport',
#         'FordEcosport1.0ECOBOOST', 'FordEcosport1.5AMBIENTE',
#         'FordEcosport1.5TDCITITANIUM', 'FordEcosport1.5TITANIUM',
#         'FordEcosport1.5TITANIUMPLUSTIVCT', 'FordEcosport1.5TITANIUMTDCI',
#         'FordEcosport1.5TITANIUMTI', 'FordEcosport1.5TITANIUMTIVCT',
#         'FordEcosport1.5TREND', 'FordEcosport1.5TRENDTI',
#         'FordFiestaTREND', 'FordFigo1.2EXI', 'FordFigo1.2TITANIUM',
#         'FordFigo1.2ZXI', 'FordFigo1.4EXI', 'FordFigoAspire1.2AMBIENTE',
#         'FordFigoAspire1.5TITANIUM', 'FordFigoAspire1.5TREND',
#         'FordNewFigo1.5TITANIUMAT', 'HondaAccord2.4ATI',
#         'HondaAmaze1.2EMTI', 'HondaAmaze1.2EXMTI', 'HondaAmaze1.2SATI',
#         'HondaAmaze1.2SMTI', 'HondaAmaze1.2VCVTI', 'HondaAmaze1.2VMT',
#         'HondaAmaze1.2VXMTI', 'HondaAmaze1.5EMTI', 'HondaAmaze1.5EXMTI',
#         'HondaAmaze1.5SMTI', 'HondaAmaze1.5SXMTI', 'HondaAmaze1.5VCVT',
#         'HondaAmaze1.5VXMTI', 'HondaBR-V1.5i-VTEC', 'HondaBrio1.2EMTI',
#         'HondaBrio1.2EXMTI', 'HondaBrio1.2SMTI', 'HondaBrio1.2V',
#         'HondaBrio1.2VMTI', 'HondaBrio1.2VXATI', 'HondaBrio1.2VXMTI',
#         'HondaCRV2.4AT4WD', 'HondaCity1.5EMT', 'HondaCity1.5V',
#         'HondaCitySMT', 'HondaCitySVCVT', 'HondaCitySVMT', 'HondaCityV',
#         'HondaCityVMT', 'HondaCityVX(O)', 'HondaCityVXCVT',
#         'HondaCityVXMT', 'HondaCityVXMTO', 'HondaCityZX', 'HondaCityZX1.5',
#         'HondaCityZX1.5VTEC', 'HondaCivic1.8S', 'HondaCivic1.8V',
#         'HondaJazz1.2BASEI', 'HondaJazz1.2SV', 'HondaJazz1.2V',
#         'HondaMobilio1.5SI', 'HondaMobilio1.5VI', 'HondaMobilio1.5VOPTI',
#         'HondaWR-V1.2i-VTECVX', 'HyundaiAccentEXECUTIVE',
#         'HyundaiCreta1.4EPLUS', 'HyundaiCreta1.4S', 'HyundaiCreta1.6',
#         'HyundaiCreta1.6CRDISXPLUS', 'HyundaiCreta1.6E+',
#         'HyundaiCreta1.6SX', 'HyundaiCreta1.6SX(O)', 'HyundaiCreta1.6SXAT',
#         'HyundaiCreta1.6SXPLUS', 'HyundaiCreta1.6SXPLUSAUTO',
#         'HyundaiElitei201.2MAGNAPLUS', 'HyundaiElitei201.2SPORTSPLUS',
#         'HyundaiElitei201.4CRDIASTA', 'HyundaiElitei20ASTA',
#         'HyundaiElitei20ASTA1.2', 'HyundaiElitei20ASTA1.2DUAL',
#         'HyundaiElitei20ASTA1.4', 'HyundaiElitei20ERA',
#         'HyundaiElitei20MAGNA', 'HyundaiElitei20MAGNA1.4',
#         'HyundaiElitei20MagnaExecutive', 'HyundaiElitei20SPORTZ',
#         'HyundaiElitei20SPORTZ(O)', 'HyundaiElitei20Sportz(O)1.4CRDi',
#         'HyundaiEon', 'HyundaiEonD', 'HyundaiEonDLITE', 'HyundaiEonERA',
#         'HyundaiEonERAPLUS', 'HyundaiEonMAGNA',
#         'HyundaiGRANDI10NIOSSPORTZ1.2', 'HyundaiGrandi101.2ASTA(O)',
#         'HyundaiGrandi10ASTA1.1(O)', 'HyundaiGrandi10ASTA1.2AT',
#         'HyundaiGrandi10ASTA1.2KAPPA', 'HyundaiGrandi10ASTAAT1.2KAPPA',
#         'HyundaiGrandi10ERA1.2', 'HyundaiGrandi10MAGNA1.2',
#         'HyundaiGrandi10MAGNA1.2KAPPA', 'HyundaiGrandi10Magna1.2AT',
#         'HyundaiGrandi10SPORTS1.2', 'HyundaiGrandi10SPORTZ(O)1.2AT',
#         'HyundaiGrandi10SPORTZ1.1', 'HyundaiGrandi10SPORTZ1.1CRDISPECIAL',
#         'HyundaiGrandi10SPORTZ1.2KAPPA', 'HyundaiGrandi10SPORTZAT1.2KAPPA',
#         'HyundaiGrandi10SPORTZO', 'HyundaiGrandi10Sportz(O)1.2',
#         'HyundaiGrandi10Sportz1.2', 'HyundaiNEWSANTRO1.1MAGNACNG',
#         'HyundaiNEWSANTROASTA1.1', 'HyundaiNEWSANTROSPORTZ',
#         'HyundaiNewElantraS1.6', 'HyundaiSantroXing',
#         'HyundaiSantroXingGL', 'HyundaiSantroXingGLS',
#         'HyundaiSantroXingXLERLXEURO', 'HyundaiSantroXingXOERLXEURO',
#         'HyundaiTucsonNew2WDATGLS', 'HyundaiVENUE1.0LTurboGDISX',
#         'HyundaiVENUE1.0LTurboGDISX(O)', 'HyundaiVENUE1.0TURBOGDISX+',
#         'HyundaiVENUE1.4CRDIMT', 'HyundaiVENUESMT1.2', 'HyundaiVerna',
#         'HyundaiVerna1.6SX(O)CRDI', 'HyundaiVerna1.6SXVTVTAT',
#         'HyundaiVernaFLUIDIC1.4', 'HyundaiVernaFLUIDIC1.4CRDI',
#         'HyundaiVernaFLUIDIC1.6CRDISX', 'HyundaiVernaFLUIDIC1.6CRDISXOPT',
#         'HyundaiVernaFLUIDIC1.6EX', 'HyundaiVernaFLUIDIC1.6EXCRDI',
#         'HyundaiVernaFLUIDIC1.6SX', 'HyundaiVernaFLUIDIC1.6SXCRDI',
#         'HyundaiVernaFLUIDIC1.6SXVTVT', 'HyundaiVernaFLUIDIC1.6SXVTVTOPT',
#         'HyundaiXcentS', 'HyundaiXcentS1.2', 'HyundaiXcentSX',
#         'HyundaiXcentSX1.1', 'HyundaiXcentSX1.1CRDI', 'Hyundaii10',
#         'Hyundaii10ASTA1.2', 'Hyundaii10ASTA1.2ATKAPPA2WITH',
#         'Hyundaii10ERA1.1', 'Hyundaii10MAGNA', 'Hyundaii10MAGNA1.1',
#         'Hyundaii10MAGNA1.2', 'Hyundaii10SPORTZ', 'Hyundaii10SPORTZ1.1',
#         'Hyundaii10SPORTZ1.2', 'Hyundaii10SPORTZ1.2AT', 'Hyundaii20ASTA',
#         'Hyundaii20ASTA1.4', 'Hyundaii20Active1.2', 'Hyundaii20ERA',
#         'Hyundaii20MAGNA1.2', 'Hyundaii20MAGNA1.4', 'Hyundaii20MAGNAO',
#         'Hyundaii20MAGNAO1.4', 'Hyundaii20SPORTZ1.2',
#         'Hyundaii20SPORTZ1.4', 'Hyundaii20SPORTZO1.4',
#         'JeepCompass2.0LIMITED', 'JeepCompassLIMITED1.4',
#         'MGHECTORSHARPDCT', 'MahindraBoleroPower+', 'MahindraKuv100K46',
#         'MahindraKuv100K6D6', 'MahindraMARAZZOM28', 'MahindraMARAZZOM87',
#         'MahindraScorpio', 'MahindraScorpioS6', 'MahindraScorpioSLEBS',
#         'MahindraTUV300', 'MahindraTUV300T8', 'MahindraTharCRDE4X4BS',
#         'MahindraXUV3OO', 'MahindraXUV500', 'MahindraXUV500W10',
#         'MahindraXUV500W11', 'MahindraXUV500W6', 'MahindraXUV500W8',
#         'MarutiAStar', 'MarutiAStarVXIABS', 'MarutiAlto', 'MarutiAlto800',
#         'MarutiAlto800LXI', 'MarutiAltoK10', 'MarutiAltoK10K10VXI',
#         'MarutiAltoK10LXI', 'MarutiAltoK10VXI', 'MarutiAltoK10VXI(O)',
#         'MarutiAltoLXI', 'MarutiBalenoALPHA1.2', 'MarutiBalenoALPHADDIS',
#         'MarutiBalenoDELTA1.2', 'MarutiBalenoDELTA1.2K12',
#         'MarutiBalenoDELTADDIS', 'MarutiBalenoSIGMA1.2',
#         'MarutiBalenoZETA1.2', 'MarutiBalenoZETA1.2K12',
#         'MarutiBalenoZETADDIS', 'MarutiCelerio', 'MarutiCelerioVXI',
#         'MarutiCelerioVXI(O)', 'MarutiCelerioX', 'MarutiCelerioZXI',
#         'MarutiCelerioZXIOPT', 'MarutiCiaz', 'MarutiCiazALPHA1.3DDIS',
#         'MarutiCiazALPHA1.5ATVTVT', 'MarutiCiazALPHA1.5MTVVT',
#         'MarutiCiazDELTA1.3DDIS', 'MarutiCiazDELTA1.5SHVS',
#         'MarutiCiazDELTA1.5SHVSVVT', 'MarutiCiazVDI', 'MarutiCiazVDI+',
#         'MarutiCiazZDI+', 'MarutiCiazZDISHVS', 'MarutiCiazZETA1.4',
#         'MarutiCiazZETA1.5SHVSVVT', 'MarutiCiazZXI', 'MarutiDzire',
#         'MarutiDzireVDI', 'MarutiDzireVXI', 'MarutiDzireZXI',
#         'MarutiEeco5', 'MarutiEeco5STRCNGWITH', 'MarutiEeco5STRCNGWITHAC',
#         'MarutiEeco5STRWITHAC', 'MarutiEeco5STRWITHACPLUS', 'MarutiEeco7',
#         'MarutiErtiga', 'MarutiErtigaVDI', 'MarutiErtigaVXI',
#         'MarutiErtigaVXISMART', 'MarutiErtigaZDIPLUS',
#         'MarutiErtigaZXISMARTHYBRID', 'MarutiIGNISDELTA1.2',
#         'MarutiIGNISDELTA1.2K12', 'MarutiIGNISZETA1.2K12',
#         'MarutiNewWagon-R1.0LXI', 'MarutiNewWagon-R1.0Lxi(o)',
#         'MarutiNewWagon-RLXI1.0', 'MarutiNewWagon-RLXICNG1.0',
#         'MarutiNewWagon-RVXI', 'MarutiOMNIE8', 'MarutiRitz',
#         'MarutiRitzVXI', 'MarutiRitzVXIABS', 'MarutiRitzVXIBS',
#         'MarutiRitzZXI', 'MarutiSCrossSIGMA', 'MarutiSCrossZETA',
#         'MarutiSX4', 'MarutiSX4ZXIMTLEATHERBS', 'MarutiSwift',
#         'MarutiSwiftDzire', 'MarutiSwiftDzireLDIBS',
#         'MarutiSwiftDzireLXI1.2BS', 'MarutiSwiftDzireVDI',
#         'MarutiSwiftDzireVDIBS', 'MarutiSwiftDzireVXI',
#         'MarutiSwiftDzireVXI1.2BS', 'MarutiSwiftDzireZXI',
#         'MarutiSwiftDzireZXI1.2BS', 'MarutiSwiftLDIBS', 'MarutiSwiftLXI',
#         'MarutiSwiftVDI', 'MarutiSwiftVDIGlory', 'MarutiSwiftVXI',
#         'MarutiSwiftVXI1.3', 'MarutiSwiftVXILIMITED', 'MarutiSwiftZDI',
#         'MarutiSwiftZXI', 'MarutiSwiftZXI+BS', 'MarutiSwiftZXIPLUS',
#         'MarutiVitaraBrezza', 'MarutiVitaraBrezzaLDI',
#         'MarutiVitaraBrezzaVDI', 'MarutiVitaraBrezzaZDI',
#         'MarutiVitaraBrezzaZDI+', 'MarutiVitaraBrezzaZDIPLUSDUAL',
#         'MarutiWagonR', 'MarutiWagonR1.0', 'MarutiWagonR1.0LXI',
#         'MarutiWagonR1.0LXICNG', 'MarutiWagonR1.0LXICNGLIMITED',
#         'MarutiWagonR1.0VXI', 'MarutiWagonR1.0VXI+(O)',
#         'MarutiWagonR1.0VXIOPT', 'MarutiWagonRDuoLXI',
#         'MarutiWagonRStingray', 'MarutiWagonRVXIBS', 'MarutiZenEstilo',
#         'MercedesBenzCClass220EDITION', 'MercedesBenzEClassE250',
#         'MercedesBenzGLAClass200CDI', 'NissanMicraXEPLUS',
#         'NissanMicraXVPREMIUM', 'NissanSunnyXL', 'NissanSunnyXV',
#         'NissanTerranoXL110', 'NissanTerranoXLOPT85',
#         'NissanTerranoXLPLUS85PS', 'RenaultDuster85PS',
#         'RenaultDuster85PSRXL', 'RenaultDusterRXLAMT110',
#         'RenaultDusterRXLDIESEL', 'RenaultDusterRXZ110',
#         'RenaultDusterRXZ85PS', 'RenaultDusterRXZAMT110',
#         'RenaultDusterRXZDIESEL', 'RenaultKwid', 'RenaultKwid1.0',
#         'RenaultKwid1.0RXT', 'RenaultKwidCLIMBER', 'RenaultKwidCLIMBER1.0',
#         'RenaultKwidRXL1.0EASY-R', 'RenaultKwidRXT',
#         'RenaultKwidRXT1.0EASY-R', 'RenaultKwidRXT1.0EASY-RAT',
#         'RenaultLodgy110PSRXZ8', 'SkodaFabiaAMBIENTE1.2',
#         'SkodaFabiaELEGANCE1.2', 'SkodaLauraAMBIENTE2.0TDICR',
#         'SkodaLauraAMBITION2.0TDICR', 'SkodaLauraELEGANCE2.0TDICR',
#         'SkodaRapid1.5ACTIVETDI', 'SkodaRapid1.5TDIAT',
#         'SkodaRapid1.5TDIMT', 'SkodaRapid1.5TDIMTAmbition',
#         'SkodaRapid1.6TDIMT', 'SkodaRapid1.6TDIMTAMBITION',
#         'SkodaRapidELEGANCE1.6MPFI', 'SkodaRapidELEGANCE1.6TDI',
#         'SkodaSuperb1.8TSISTYLE', 'SkodaSuperbELEGANCE1.8TSI',
#         'SkodaSuperbELEGANCETDI2.0', 'SsangyongRexton',
#         'TataHexaVaricor400', 'TataIndicaVistaAURA1.3',
#         'TataIndicaVistaVX', 'TataNEXONXM', 'TataNEXONXMA', 'TataNEXONXZ+',
#         'TataNano', 'TataNanoTWIST', 'TataNanoXT', 'TataTIAGOJTP',
#         'TataTIGORRevotron', 'TataTiagoXT1.05', 'TataTiagoXT1.2',
#         'TataTiagoXZ1.05', 'TataTiagoXZ1.2', 'TataTiagoXZA1.2',
#         'TataZestXMAQUADRAJET', 'ToyotaCorollaAltis',
#         'ToyotaCorollaAltis1.8', 'ToyotaCorollaAltisD4D',
#         'ToyotaCorollaAltisJ', 'ToyotaCorollaAltisVL',
#         'ToyotaCorollaH21.8', 'ToyotaCorollaH31.8', 'ToyotaCorollaHE1.8',
#         'ToyotaEtios', 'ToyotaEtiosCROSS', 'ToyotaEtiosCROSS1.4',
#         'ToyotaEtiosGD', 'ToyotaEtiosLiva', 'ToyotaEtiosLivaD4D',
#         'ToyotaEtiosLivaD4DGD', 'ToyotaEtiosLivaG', 'ToyotaEtiosLivaGD',
#         'ToyotaEtiosLivaV', 'ToyotaEtiosVX', 'ToyotaFortuner3.0AT',
#         'ToyotaFortuner3.0MT', 'ToyotaInnova2.5GX7STRBS',
#         'ToyotaInnova2.5GX8STRBS', 'ToyotaInnova2.5V',
#         'ToyotaInnova2.5VX7STRBS', 'ToyotaInnova2.5VX8STRBS',
#         'ToyotaInnovaCrysta2.4GX7', 'ToyotaInnovaCrysta2.4GX8',
#         'ToyotaInnovaCrysta2.4VX7', 'ToyotaInnovaCrysta2.4VX8',
#         'ToyotaInnovaCrysta2.8ZXAT7', 'ToyotaYARISJ',
#         'VolkswagenJettaCOMFORTLINE2.0L', 'VolkswagenJettaTRENDLINE2.0L',
#         'VolkswagenPassatHIGHLINE', 'VolkswagenPoloCOMFORTLINE1.2L',
#         'VolkswagenPoloCOMFORTLINE1.5L', 'VolkswagenPoloGT',
#         'VolkswagenPoloGTTSI1.2PETROL', 'VolkswagenPoloHIGHLINE1.2L',
#         'VolkswagenPoloHIGHLINE1.5L', 'VolkswagenPoloHIGHLINE1.6L',
#         'VolkswagenPoloTRENDLINE1.2L', 'VolkswagenPoloTrendline1.0L',
#         'VolkswagenVentoCOMFORTLINE', 'VolkswagenVentoCOMFORTLINEMT',
#         'VolkswagenVentoHIGHLINE', 'VolkswagenVentoHIGHLINE1.2TSI',
#         'VolkswagenVentoHIGHLINEPETROL', 'VolkswagenVentoHIGHLINETDI',
#         'VolkswagenVentoTRENDLINE'], dtype=object),
#  array([   913,   1424,   1475, ..., 227458, 247836, 855881], dtype=int64),
#  array(['Diesel', 'Petrol', 'Petrol + CNG', 'Petrol + LPG'], dtype=object),
#  array(['First Owner', 'Second Owner', 'Third Owner'], dtype=object),
#  array(['AUTOMATIC', 'MANUAL'], dtype=object)]

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Model','Kilometers Driven','Fuel Type','Owner','Transmission'])
                                      ,remainder="passthrough")

# %%
lr=LinearRegression()

# %% [markdown]
# Then we create our pipeline object,

# %%
pipe =make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['AudiA62.0', 'AudiA62.0TDIPREMIUM', 'AudiQ335TDI', 'BMW3Series',
#        'BMW3Series320D', 'BMW5Series', 'BMWX1SDRIVE', 'ChevroletBeatPS',
#        'ChevroletCruzeLTZ', 'ChevroletSparkLS', 'DatsunGo',
#        'DatsunGoREMIX', 'DatsunRediGo', 'Da...
#        'VolkswagenVentoTRENDLINE'], dtype=object),
#                                                                             array([   913,   1424,   1475, ..., 227458, 247836, 855881], dtype=int64),
#                                                                             array(['Diesel', 'Petrol', 'Petrol + CNG', 'Petrol + LPG'], dtype=object),
#                                                                             array(['First Owner', 'Second Owner', 'Third Owner'], dtype=object),
#                                                                             array(['AUTOMATIC', 'MANUAL'], dtype=object)]),
#                                                   ['Model', 'Kilometers Driven',
#                                                    'Fuel Type', 'Owner',
#                                                    'Transmission'])])),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# We now can evaluate our model on our hold out test set using the accuracy metric.

# %%
y_pred=pipe.predict(X_test)

y_pred
# Out:
# array([ 413626.27824087,  457549.95343451,  304392.57986342,
#         324819.21878247,  224274.66359313,  231692.83319049,
#         459612.71001742,  570112.34384291,  286285.63175806,
#         433464.73256511,  327497.95920857,  538988.6373778 ,
#         263180.25241291,  321289.44342081,  457549.95343451,
#         527913.29229025,  408088.46739867,  469863.66590712,
#         374082.42575123,  263180.25241291,  589269.15312026,
#         469863.66590712,  337460.11673219,  354846.24267606,
#         579038.89556965,  353905.16736613,  413626.27824087,
#         392252.4051146 ,  456823.60446887,  241976.86648175,
#         413626.27824087,  464392.81613214,  316027.33355599,
#         218568.02559298,  316027.33355599,  278477.87668876,
#         538988.6373778 ,  316027.33355599,  286285.63175806,
#         360691.94179699,  396640.0382857 ,  404899.76157031,
#         291720.6401435 ,  312917.54217302,  538988.6373778 ,
#         571042.42947942,  497776.30992729,  583173.82436445,
#         457549.95343451,  283189.19393226,  408088.46739867,
#         327497.95920857,  538988.6373778 ,  409311.26605404,
#         300343.78188968,  404899.76157031,  401904.2692475 ,
#         148099.97310024,  633538.31145838,  287164.24808396,
#         460328.08737777,  245750.98332212,  419115.75992726,
#         337677.07598396,  212649.96052667,  517568.15671241,
#         266511.35756448,  321289.44342081,  469863.66590712,
#         564134.28689719,  461200.93087812,  487694.10631187,
#         364210.31853663,  538988.6373778 ,  457549.95343451,
#         366876.13994815,  274815.00610548,  517568.15671241,
#         413896.47925496,  460328.08737777,  308421.35094173,
#         401904.2692475 ,  312917.54217302,  283189.19393226,
#         451385.57708289,  316027.33355599,  238121.48797224,
#         445649.00247992,  619064.85999266,  460328.08737777,
#         283189.19393226,  619385.80434357,  274527.80113998,
#         408088.46739867,  445649.00247992,  508772.97989335,
#         408088.46739867,  331330.72953348,  337460.11673219,
#         286285.63175806,  282889.2549093 ,  589269.15312026,
#         460328.08737777,  538988.6373778 ,  564134.28689719,
#         564465.83455887,  320465.58530421,  378889.40343447,
#         401798.78202622,  324101.58235981,  538988.6373778 ,
#         425495.80540948,  405933.44295361,  633538.31145838,
#         378889.40343447,  354846.24267606,  454142.20049674,
#         408088.46739867,  372413.95079036,  832086.72066281,
#         144283.45575727,  419988.60342761,  633538.31145838,
#         321805.11015847,  364210.31853663,  465057.22534812,
#         185471.13756875,  956724.9378657 ,  445649.00247992,
#         576060.26796862,  463552.19769558,  363017.43760899,
#         580117.14174564,  327497.95920857,  498356.84591311,
#         223354.1353741 ,  283189.19393226,  316027.33355599,
#         327497.95920857,  274815.00610548,  408088.46739867,
#         226683.46501926,  637580.26402004,  592325.98400787,
#         453580.5367871 ,  413626.27824087,  489428.30088916,
#         304392.57986342,  553892.02201258,  266511.35756448,
#         473025.83657536,  425495.80540948,  333701.84376836,
#         612833.90442303,  430395.77611562,  619960.01931344,
#         567958.35258584,  581050.41396896,  378889.40343447,
#         376846.90954021,  538988.6373778 ,  408088.46739867,
#         283189.19393226,  589269.15312026,  463552.19769558,
#         358514.8724112 ,  670707.83706356,  272905.160641  ,
#         576060.26796862,  413626.27824087,  250508.31269299,
#         364210.31853663,  401904.2692475 ,  408088.46739867,
#         276377.92388644,  363687.4341198 ,  584044.23205823,
#         405933.44295361,  746684.98020718,  381266.08585594,
#         304392.57986342,  538988.6373778 ,  304392.57986342,
#         304392.57986342,  280077.1159703 ,  413626.27824087,
#         638379.42044237,  389884.97290192,  538988.6373778 ,
#         507303.38732774,  408088.46739867,  571042.42947942,
#         433464.73256511,  408088.46739867,  404899.76157031,
#         304392.57986342,  283189.19393226,  383141.56573726,
#         756138.409435  ,  457549.95343451,  433632.52225768,
#         559896.3533819 ,  670707.83706356,  272905.160641  ,
#         504792.28864641,  167122.33535886,  312917.54217302,
#         508772.97989335,  328376.57553447,  159160.45734473,
#         212649.96052667,  272905.160641  ,  413626.27824087,
#         430395.77611562,  408088.46739867,  583173.82436445,
#         283189.19393226,  229628.50983747,  390289.46629011,
#         202130.80064217,  352772.03460599,  538988.6373778 ,
#         461200.93087812,  589269.15312026,  378889.40343447,
#         413626.27824087,  303491.1202434 ,  383674.148004  ,
#         457549.95343451,  528212.2033492 ,  316027.33355599,
#         542680.75596474,  413626.27824087,  531395.22047974,
#         464392.81613214,  600239.78457082,  241976.86648175,
#         378779.26563472,  553684.90817585,  341576.27516992,
#         241976.86648175,  408088.46739867,  327497.95920857,
#         528212.2033492 ,  274521.98074185,  922343.25076275,
#         994419.64131803,  245956.5439066 ,  321289.44342081,
#         235124.615474  ,  357393.02260842,  241976.86648175,
#         327497.95920857,  460328.08737777,  468142.2248619 ,
#         283189.19393226,  223667.21360919,  536592.34399013,
#         625256.55950874,  320460.55236908,  746684.98020718,
#         212649.96052667,  285804.82463886,  408042.10791312,
#         431813.50912485,  353905.16736613,  269854.86633026,
#         378889.40343447,  307465.16592986,  311067.19378077,
#         167653.4354795 ,  461200.93087812,  366876.13994815,
#         252922.93865142,  538988.6373778 ,  374082.42575123,
#         316027.33355599,  464580.24968056,  413626.27824087,
#         390289.46629011,  489610.26951039,  997937.26531621,
#         304392.57986342,  272905.160641  ,  653148.47704556,
#         304392.57986342,  457549.95343451,  408088.46739867,
#         272905.160641  ,  526746.02513533,  756138.409435  ,
#         361186.45384769,  274521.98074185,  274521.98074185,
#         460328.08737777,  307465.16592986,  621329.46919615,
#         818223.86932522,  360173.10317401,  457549.95343451,
#        1023793.24090958,  378889.40343447,  327497.95920857,
#         304392.57986342,  208334.66280937,  378889.40343447,
#         612833.90442303,  307723.68501499,  404436.67502941,
#         401798.78202622,  408088.46739867,  460328.08737777,
#         283189.19393226,  307723.68501499,  333037.79080571,
#         525923.72472835,  388526.67945452,  354119.9888769 ,
#         383141.56573726,  445649.00247992,  307723.68501499,
#         567958.35258584,  419115.75992726,  320589.93279372,
#         229628.50983747,  369039.72883864,  464739.36658941,
#         387081.90094177,  551438.6871908 ,  295086.16871878,
#         461200.93087812,  469863.66590712,  341929.23828675,
#         354209.94109671,  305229.84792086,  321805.11015847,
#         359511.17938368,  460328.08737777,  405933.44295361,
#         337677.07598396,  344834.16907266,  487249.95253912,
#         470000.00324751,  404899.76157031,  487249.95253912,
#         382338.21117017,  457549.95343451,  360173.10317401,
#         418921.58070473,  469863.66590712,  818223.86932522,
#         609066.14987965,  392420.19480717,  583893.08341525,
#         418400.38256691,  511073.69888387,  358514.8724112 ,
#         284218.97879343,  366876.13994815,  337460.11673219,
#         311067.19378077,  337677.07598396,  319821.41379737,
#         421711.28763461,  517568.15671241,  311067.19378077,
#         756138.409435  ,  571042.42947942,  559896.3533819 ,
#         464497.13011909,  312809.25793006,  534003.21075763,
#         263180.25241291,  283189.19393226,  464529.96284925,
#         312917.54217302,  401904.2692475 ,  263180.25241291,
#         437705.33111395,  462802.8023589 ,  300403.18893647,
#         281585.99252721,  408088.46739867,  413626.27824087,
#         316027.33355599,  237255.63252225,  385053.05720179,
#         281126.30321905,  311067.19378077,  363017.43760899,
#         497776.30992729,  312917.54217302,  287697.24030512,
#         756138.409435  ,  497776.30992729,  366876.13994815,
#         360173.10317401,  613367.32314023,  477826.35610322,
#         464392.81613214,  675984.72691385,  408088.46739867,
#         327497.95920857,  416337.625984  ,  328376.57553447,
#         446481.77886136,  212649.96052667,  562060.57365467,
#         212649.96052667,  216619.79906872,  312673.51324452,
#         956724.9378657 ,  460328.08737777,  427218.95154312,
#         473025.83657536,  404929.85912328,  241976.86648175,
#         304392.57986342,  413626.27824087,  665192.2902883 ,
#         457549.95343451,  555076.30210158,  340528.84419097,
#         408088.46739867,  238056.25849307,  905648.33518422,
#         190172.36681441,  536592.34399013,  856134.05316534,
#         212649.96052667,  318334.58632017,  231692.83319049,
#         218568.02559298,  327497.95920857,  538988.6373778 ,
#         241976.86648175,  398119.46294998,  460328.08737777,
#         372413.95079036,  252114.40862469,  307723.68501499,
#         413896.47925496,  413626.27824087,  672564.24088539,
#         369039.72883864,  413626.27824087,  350899.83542346])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6171218788729498

# %% [markdown]
# Finally test the trained model , By passing new records

# %%
pipe.predict(pd.DataFrame([['MarutiWagonR1.0LXI',82238,'Petrol','First Owner','MANUAL']],columns=['Model','Kilometers Driven','Fuel Type','Owner','Transmission']))
# Out:
# array([352688.02054414])

# %% [markdown]
# As we can we have successfully got the results .
